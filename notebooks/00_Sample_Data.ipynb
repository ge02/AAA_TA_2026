# %% [markdown]
# # 0 Sample Data Generation
#
# In this notebook we generate sample data for each state of both the trip and weather (and merged) datasets for an easier and faster exemplary compliation of our notebooks. Please keep in mind that we sample the data randomly, therefore the sampled data is solely an exemplary (not perfect) representation of our datasets and some patterns etc. are not represented in the sampled datasets.
#
# For the sampling we decided to sample the datasets down to a total of approx. 10.000 - 15.000 rows, keeping all columns.

# %% [markdown]
# All of our data can be found in the following sciebo folder: https://uni-koeln.sciebo.de/s/z5xgdGosd9y9c4e (Password: AAA2026)

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Import packages                         #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

import pandas as pd

# reset working dir
import os
from pathlib import Path

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Reset working directory                 #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

def find_project_root():
    for parent in [Path(os.getcwd()), *Path(os.getcwd()).parents]:
        if (parent / "pyproject.toml").exists():
            return parent
    raise FileNotFoundError("Could not find pyproject.toml")

os.chdir(find_project_root())
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /Users/anthony/Documents/Dokumente – MacBook Pro von Anthony/UNI/AAA/AAA_TA_2026

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Configurations                          #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

SAMPLE_FRAC = 0.002
random_seed = 42

# %% [markdown]
# ## 0.1 Raw Chicago Trip Data
#
# First we sample the **raw** trip data downloaded from the webportal of the city of chicago: https://data.cityofchicago.org/Transportation/Taxi-Trips-2024-/ajtu-isnz/about_data (downloaded on 05.05.2026).
#
# The trip data fetching can be found here: [Raw Chicago Trip Data](01_Preprocessing/01_01_Fetch_Trip_Data.ipynb)

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Load raw trip data                      #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

raw_trip_data = pd.read_csv("data/trips/CHICAGO_TAXI_TRIPS_2025.csv")
raw_trip_data.head()
# Out:
#                                     trip_id  \
# 0  0275e2d8147a31e1ce320c5fb15f9910563cafe1
# 1  05aa05bf6f3ec476715fad9f706bd137e08e00b7
# 2  060f692c4ca69e552c07a97c99715ad51112470e
# 3  0b2d1368456148b049af41dc8aa565d688081756
# 4  17365c83264f028a307ac70308d770fe03bcbcae
#
#                                              taxi_id     trip_start_timestamp  \
# 0  84957c8960b674346784746bbc1d48cafff4976b162323...  2025-01-01T00:00:00.000
# 1  0cbf5c0f6aca3628d77c7b6fe89715757ed402a70b0f8b...  2025-01-01T00:00:00.000
# 2  e533bfdc483206f9c02c1c879a118d88f0a3ca1cd2703f...  2025-01-01T00:00:00.000
# 3  2d5029b701200a2ab66bd5071f743efe20a3036597d2b3...  2025-01-01T00:00:00.000
# 4  c3f8e0b6712bf3ea80e75ddde065b0ed42aa530e8c40cb...  2025-01-01T00:00:00.000
#
#         trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2025-01-01T00:15:00.000         758.0        2.93                  NaN
# 1  2025-01-01T00:15:00.000        1233.0       13.66                  NaN
# ...

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Sample raw trip data                    #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

trip_sample = raw_trip_data.sample(frac=SAMPLE_FRAC, random_state=random_seed)

trip_sample.to_csv("data/samples/SAMPLE_CHICAGO_TAXI_TRIPS_2025.csv", index=False)

print(f"Sampled {len(trip_sample):,} rows ({SAMPLE_FRAC:.2%} of total)")
print(f"Saved to data/samples/SAMPLE_CHICAGO_TAXI_TRIPS_2025.csv")
# Out:
# Sampled 13,652 rows (0.20% of total)
# Saved to data/samples/SAMPLE_CHICAGO_TAXI_TRIPS_2025.csv

# %% [markdown]
# ## 0.2 Raw Chicago Weather Data
#
# For the weather data, we decided to not sample both `data/weather/weather_daily.csv`and `data/weather/weather_hourly.csv` since these two datasets have sizes of 69KB and 1.9MB. Therefore the full datasets are no problem for exemplary compilation of code.

# %% [markdown]
# # 0.3 Cleaned Trip Data
#
# Now we sample the **cleaned** taxi trip data.
#
# The trip data cleaning can be found here: [Trip Data Cleaning](01_Preprocessing/01_03_Trip_Data_Cleanup.ipynb)

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Load cleaned trip data                  #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

cleaned_trip_data = pd.read_csv("data/trips/STATE_01_04_trip_data_cleanup_V1.csv")

cleaned_trip_data.head()
# Out:
#                                     trip_id  \
# 0  0275e2d8147a31e1ce320c5fb15f9910563cafe1
# 1  05aa05bf6f3ec476715fad9f706bd137e08e00b7
# 2  17365c83264f028a307ac70308d770fe03bcbcae
# 3  1c629303d7f08492d97e13fabe6a0d1d81e6c9c5
# 4  1cb48762978a475116ec833c0e4de8ed2ac88e14
#
#                                              taxi_id trip_start_timestamp  \
# 0  84957c8960b674346784746bbc1d48cafff4976b162323...  2025-01-01 00:00:00
# 1  0cbf5c0f6aca3628d77c7b6fe89715757ed402a70b0f8b...  2025-01-01 00:00:00
# 2  c3f8e0b6712bf3ea80e75ddde065b0ed42aa530e8c40cb...  2025-01-01 00:00:00
# 3  c8f57a1150c210a9e6b3fcfb24c3d6d0a43d1879b4b979...  2025-01-01 00:00:00
# 4  88d8896a85cf755c4fb03711d495dc47ca8109196cdef6...  2025-01-01 00:00:00
#
#     trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2025-01-01 00:15:00         758.0        2.93         1.703108e+10
# 1  2025-01-01 00:15:00        1233.0       13.66         1.703176e+10
# ...

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Sample cleaned trip data                #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

trip_sample = cleaned_trip_data.sample(frac=SAMPLE_FRAC, random_state=random_seed)

trip_sample.to_csv("data/samples/SAMPLE_CHICAGO_TAXI_TRIPS_2025.csv", index=False)

print(f"Sampled {len(trip_sample):,} rows ({SAMPLE_FRAC:.2%} of total)")
print(f"Saved to data/samples/SAMPLE_cleaned_trips.csv")
# Out:
# Sampled 11,274 rows (0.20% of total)
# Saved to data/samples/SAMPLE_cleaned_trips.csv

# %% [markdown]
# # 0.4 Merged Trip and Weather Data
#
# After cleaning we merged the trip data with weather data.
#
# The merging can be found in this notebook: [Trip Weather Data Merge](01_Preprocessing/01_05_Trips_Weather_Merge.ipynb)

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Load merged trip data                   #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

merged = pd.read_csv("data/merged/state_01_05_MERGED_TRIPS_WEATHER.csv")

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Sample merged data                      #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

trip_sample = merged.sample(frac=SAMPLE_FRAC, random_state=random_seed)

trip_sample.to_csv("data/samples/SAMPLE_CHICAGO_TAXI_TRIPS_2025.csv", index=False)

print(f"Sampled {len(trip_sample):,} rows ({SAMPLE_FRAC:.2%} of total)")
print(f"Saved to data/samples/SAMPLE_merged_trips_weather.csv")
# Out:
# Sampled 11,274 rows (0.20% of total)
# Saved to data/samples/SAMPLE_merged_trips_weather.csv

# %% [markdown]
# # 0.4 Aggregated Data
#
# Now we sample the aggregated trip and weather data.
#
# The data aggregation can be found in this notebook: [Data Aggregation](01_Preprocessing/01_06_Data_Aggregation.ipynb)

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Load aggregated data                    #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

demand_= pd.read_csv("data/aggregated/state_01_05_MERGED_TRIPS_WEATHER.csv")
