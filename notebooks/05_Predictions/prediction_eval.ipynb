# %% [markdown]
# # Prediction Evaluation
#
# This might be a temporary notebook.
#
# In this notebook we look at the history of the results of the Neural Network evaluations.

# %%
import pandas as pd

# reset working dir
import os
from pathlib import Path

# %%
# # # # # # # # # # # # # # # # # # # # # #
#                                         #
# Reset working directory                 #
#                                         #
# # # # # # # # # # # # # # # # # # # # # #

import __main__
_nb = getattr(__main__, "__vsc_ipynb_file__", None) or os.environ.get("JPY_SESSION_NAME")
_start = Path(_nb).resolve().parent if _nb else Path.cwd()
os.chdir(next(p for p in [_start, *_start.parents] if (p / "pyproject.toml").exists()))
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /Users/anthony/Documents/Dokumente – MacBook Pro von Anthony/UNI/AAA/AAA_TA_2026

# %%
ca_1 = pd.read_csv("data/results/nn_results_ca_1h.csv", index_col=0, parse_dates=True)

# %%
ca_1
# Out:
#                               model  n_layers  width  learning_rate  \
# timestamp
# 2026-06-29 16:23:24        baseline         2     64        0.00005
# 2026-06-29 16:23:24        baseline         2     64        0.00005
# 2026-06-29 16:23:24        baseline         2     64        0.00005
# 2026-06-29 16:23:24        baseline         2     64        0.00005
# 2026-06-29 16:23:24        baseline         2     64        0.00005
# ...                             ...       ...    ...            ...
# 2026-07-09 14:36:47  baseline_tuned         2     64        0.00700
# 2026-07-09 14:37:58            deep         8     64        0.00005
# 2026-07-09 14:47:30      deep_tuned         8     64        0.00400
# 2026-07-09 14:48:23            wide         2    256        0.00005
# 2026-07-09 15:03:19     wider_tuned         2    256        0.00500
#
#                      batch_size  seed  val_loss  zero_demand_count  \
# timestamp
# ...

# %%
wd = ca_1[ca_1['weight_decay'] == 0.0]
no_wd = ca_1[ca_1['weight_decay'] != 0.0]

# %%
wd = wd.tail(9)
wd
# Out:
#                               model  n_layers  width  learning_rate  \
# timestamp
# 2026-07-09 13:47:22      deep_tuned         8     64        0.00700
# 2026-07-09 13:48:44            wide         2    256        0.00005
# 2026-07-09 14:02:21     wider_tuned         2    256        0.00300
# 2026-07-09 14:07:18        baseline         2     64        0.00005
# 2026-07-09 14:10:52  baseline_tuned         2     64        0.00900
# 2026-07-09 14:12:18            deep         8     64        0.00005
# 2026-07-09 14:26:05        baseline         2     64        0.00005
# 2026-07-09 14:37:58            deep         8     64        0.00005
# 2026-07-09 14:48:23            wide         2    256        0.00005
#
#                      batch_size  seed  val_loss  zero_demand_count  \
# timestamp
# 2026-07-09 13:47:22        1024     0  0.299351              51971
# 2026-07-09 13:48:44        1024     0  0.305792              51971
# ...

# %%
no_wd
# Out:
#                               model  n_layers  width  learning_rate  \
# timestamp
# 2026-07-09 14:36:47  baseline_tuned         2     64          0.007
# 2026-07-09 14:47:30      deep_tuned         8     64          0.004
# 2026-07-09 15:03:19     wider_tuned         2    256          0.005
#
#                      batch_size  seed  val_loss  zero_demand_count  \
# timestamp
# 2026-07-09 14:36:47        1024     0  0.186020              51971
# 2026-07-09 14:47:30        1024     0  0.184116              51971
# 2026-07-09 15:03:19        1024     0  0.185500              51971
#
#                      mean_actual        r2  ...  rmse_log  nrmse_log  \
# timestamp                                   ...
# 2026-07-09 14:36:47     7.529611  0.814400  ...  0.456305   0.588291
# 2026-07-09 14:47:30     7.529611  0.842105  ...  0.454544   0.586022
# 2026-07-09 15:03:19     7.529611  0.749853  ...  0.467287   0.602450
#
# ...

# %%
comparison = pd.concat(
    [wd['model'].reset_index(drop=True).rename('model'),
     wd['r2'].reset_index(drop=True).rename('with_wd'),
     no_wd['r2'].reset_index(drop=True).rename('no_wd')],
    axis=1
)
comparison
# Out:
#             model   with_wd     no_wd
# 0      deep_tuned  0.789109  0.814400
# 1            wide  0.784912  0.842105
# 2     wider_tuned  0.789697  0.749853
# 3        baseline  0.768623       NaN
# 4  baseline_tuned  0.822594       NaN
# 5            deep  0.781440       NaN
# 6        baseline  0.768623       NaN
# 7            deep  0.781440       NaN
# 8            wide  0.764380       NaN
